# %% [markdown]
# <a href="https://colab.research.google.com/github/CopotronicRifat/Embedding/blob/main/LIBVIPS_EMBED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! apt-get update
! apt install libvips libvips-dev libvips-tools
! pip install pyvips
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [500 kB]
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-2-d1d5f2f639c4> in <module>()
#       3 device_name = tf.test.gpu_device_name()
#       4 if device_name != '/device:GPU:0':
# ----> 5   raise SystemError('GPU device not found')
#       6 print('Found GPU at: {}'.format(device_name))
#
# SystemError: GPU device not found

# %%
import os 
import logging
import pyvips
from google.colab import drive
import IPython
import urllib

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filen = []
x = []
y = []
wh = []

# %%
with open("/content/drive/MyDrive/Colab Notebooks/EMBED.txt", "r") as filestream:
    for line in filestream:
        currentline = line.split(",")
        filen.append(currentline[0])
        x.append(int(currentline[1]))
        y.append(int(currentline[2]))

# %%
print(filen)
print(x)
print(y)
# Out:
# ['cutlery_mesh_S5_S5-2\\cutlery_mesh_S5_S5-2_0045.png', 'cutlery_mesh_S5_S5-2\\cutlery_mesh_S5_S5-2_0021.png', 'cutlery_mesh_S5_S5-2\\cutlery_mesh_S5_S5-2_0181.png', 'cutlery_mesh_S5_S5-2\\cutlery_mesh_S5_S5-2_0165.png', 'cutlery_mesh_S5_S5-2\\cutlery_mesh_S5_S5-2_0149.png', 'cutlery_mesh_S1_S1-1\\cutlery_mesh_S1_S1-1_0073.png', 'cutlery_mesh_S1_S1-1\\cutlery_mesh_S1_S1-1_0105.png', 'cutlery_mesh_S1_S1-1\\cutlery_mesh_S1_S1-1_0177.png', 'cutlery_mesh_S1_S1-1\\cutlery_mesh_S1_S1-1_0197.png', 'cutlery_mesh_S1_S1-1\\cutlery_mesh_S1_S1-1_0121.png', 'building_mesh_74\\building_mesh_74_0177.png', 'building_mesh_74\\building_mesh_74_0033.png', 'building_mesh_74\\building_mesh_74_0053.png', 'building_mesh_74\\building_mesh_74_0037.png', 'building_mesh_74\\building_mesh_74_0161.png', 'furniture_mesh_F1_F1-1\\furniture_mesh_F1_F1-1_0069.png', 'furniture_mesh_F1_F1-1\\furniture_mesh_F1_F1-1_0133.png', 'furniture_mesh_F1_F1-1\\furniture_mesh_F1_F1-1_0113.png', 'furniture_mesh_F1_F1-1\\furniture_
# ...

# %%
from PIL import Image, ImageOps

#collage = Image.new("RGBA", (6000, 6000), color = (0, 0, 0, 0))
#im = pyvips.Image.black(6000, 6000)
#loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile.png"
c = 0

for i in range(len(x)):
    file = filen[i]
    #a = int(x[i])
    #b = int(y[i])
    photo = Image.open(file).convert("RGBA")
    photo = photo.resize((32,32))
    if(file.startswith('build')):
        
        photo = ImageOps.expand(photo, border=3, fill='#FF0000')
        #bordered.save('result.png')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('coffee')):

        photo = ImageOps.expand(photo, border=3, fill='#0000FF')
        #bordered.save('result.png')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('column')):
        
        photo = ImageOps.expand(photo, border=3, fill='#7FFD40')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tiles\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
    
    if(file.startswith('cut')):
        
        photo = ImageOps.expand(photo, border=3, fill='#FF00FF')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('demo')):
        
        photo = ImageOps.expand(photo, border=3, fill='#FFFF00')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('dish')):
        
        photo = ImageOps.expand(photo, border=3, fill='#000000')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('fur')):
        
        photo = ImageOps.expand(photo, border=3, fill='#008000')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1
        
    if(file.startswith('lamp')):
        
        photo = ImageOps.expand(photo, border=3, fill='#00008B')
        photo.save("/content/drive/MyDrive/Colab Notebooks/tile/tile"+str(i)+".png")
        #loc = "C:\\Users\\CopotronicRifat\\Python\\EMBED\\tile\\tile" + str(i) + ".png"
        #tile = pyvips.Image.new_from_file(loc)
        #im = im.insert(tile, a, b)
        #c = c+1

# %%
loc = []
for i in range(len(x)):
    loc.append("/content/drive/MyDrive/Colab Notebooks/tile/tile" + str(i) + ".png")

# %%
print(loc)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/tile/tile0.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile1.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile2.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile3.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile4.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile5.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile6.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile7.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile8.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile9.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile10.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile11.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile12.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile13.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile14.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile15.png', '/content/drive/MyDrive/Colab Notebooks/tile/tile16.png', '/content/drive/MyDri
# ...

# %%
print(len(loc))
# Out:
# 5115

# %%
from PIL import Image, ImageOps

#collage = Image.new("RGBA", (6000, 6000), color = (0, 0, 0, 0))
im = pyvips.Image.black(600000, 600000)
c=0
for i in range(len(loc)):
    #file = filen[i]
    a = int(x[i])
    b = int(y[i])
    #photo = Image.open(file).convert("RGBA")
    #photo = photo.resize((32,32))
        
        #photo = ImageOps.expand(photo, border=3, fill='#FF0000')
        #bordered.save('result.png')
    
        #collage.paste(photo, (int(a), int(b)))
    tile = pyvips.Image.new_from_file(loc[i])
    im = im.insert(tile, a, b)

    c+=1
    print(c)
#collage.show()
#collage.save("EMBEDall.png")
# Out:
# Streaming output truncated to the last 5000 lines.
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# ...

# %%
im.write_to_file("/content/drive/MyDrive/Colab Notebooks/EMBED.png")

# %%
im.dzsave("/content/drive/MyDrive/Colab Notebooks/meshdeepzoom", suffix = ".png", tile_size = 1024)
